# %% [markdown]
# # scikit-learn Master Notebook — Full Framework Map (Telugu + English)
#
# Ee notebook ni **senior ML engineer / architect** angle lo design chesanu.
#
# ## Goal
# scikit-learn ni:
# - library ga kaadu, **full ML framework** la ardham chesukovali
# - modules enti telusukovali
# - estimator API ela work chestundo clear ga undali
# - preprocessing nundi model_selection, metrics, pipelines, feature_selection, inspection, decomposition, clustering, ensembles, calibration varaku full map undali
# - real project lo ela use chestaro teliyali
#
# ## Important honesty
# scikit-learn API ecosystem chala peddaది. Prathi single function ki extreme-depth explanation oka single notebook lo complete ga rayadam huge work.
# Kabatti ee notebook lo:
# - all major modules
# - core classes/functions
# - key methods
# - real-world usage patterns
# - interview depth
# anni proper ga arrange chesanu.

# %% [markdown]
# # Part 1 — scikit-learn Philosophy and Core API

# %% [markdown]
# # 1. scikit-learn ante enti?
#
# ## English
# scikit-learn is a general-purpose machine learning framework in Python for classical ML workflows. It provides a consistent API for preprocessing, model training, evaluation, model selection, pipelines, feature engineering support, and many supervised/unsupervised algorithms.
#
# ## Telugu
# scikit-learn ante Python lo classical ML workflows kosam use ayye general-purpose machine learning framework. Preprocessing, model training, evaluation, model selection, pipelines, feature engineering support, mariyu supervised/unsupervised algorithms ki consistent API istundi.
#
# ## One-line meaning
# **scikit-learn = classical ML workflow ki standard toolkit + framework.**

# %% [markdown]
# # 2. Framework philosophy
#
# ## Main idea
# Different estimators and transformers ki oka common interface untundi.
#
# ## Why powerful?
# Once you understand:
# - fit
# - transform
# - fit_transform
# - predict
# - predict_proba
# - score
# - get_params
# - set_params
#
# almost framework usage easy avutundi.
#
# ## One-line meaning
# **Learn one API pattern, use many models.**

# %% [markdown]
# # 3. Estimator ante enti?
#
# ## English
# An estimator is any object in scikit-learn that can learn from data using `fit()`.
#
# ## Telugu
# scikit-learn lo `fit()` method use chesi data nundi nerchukune object ni estimator antaru.
#
# ## Types
# - classifier
# - regressor
# - clusterer
# - transformer
# - outlier detector
# - meta-estimator
#
# ## One-line meaning
# **Estimator = data nundi learn chese object.**

# %% [markdown]
# # 4. Transformer ante enti?
#
# ## English
# A transformer changes input data into a different representation, usually via `fit`, `transform`, or `fit_transform`.
#
# ## Telugu
# Transformer ante input data ni vere representation lo ki marache object. Usually `fit`, `transform`, `fit_transform` methods untayi.
#
# ## Examples
# - StandardScaler
# - OneHotEncoder
# - PCA
# - SimpleImputer
#
# ## One-line meaning
# **Transformer = data representation ni marchese object.**

# %% [markdown]
# # 5. Core estimator methods
#
# ## fit(X, y=None)
# Data nundi learn cheyyadam
#
# ## transform(X)
# Data ni new representation lo ki marchadam
#
# ## fit_transform(X, y=None)
# fit + transform shortcut
#
# ## predict(X)
# Predictions ivvadam
#
# ## predict_proba(X)
# Class probabilities ivvadam
#
# ## decision_function(X)
# Raw decision scores
#
# ## score(X, y)
# Default model score
#
# ## get_params()
# Hyperparameters retrieve cheyyadam
#
# ## set_params()
# Hyperparameters set/update cheyyadam
#
# ## One-line meaning
# **scikit-learn API heart = fit / transform / predict pattern.**

# %% [markdown]
# # 6. Base classes and mixins
#
# Important base/mixin concepts:
# - BaseEstimator
# - ClassifierMixin
# - RegressorMixin
# - TransformerMixin
# - ClusterMixin
# - OutlierMixin
# - MetaEstimatorMixin
#
# ## Why useful?
# Custom estimators build chestappudu sklearn conventions follow cheyyadaniki.
#
# ## One-line meaning
# **Base classes = framework conventions backbone.**

# %% [markdown]
# # 7. Global config and debugging helpers
#
# Useful top-level tools:
# - get_config()
# - set_config()
# - config_context()
# - show_versions()
#
# ## Why useful?
# - debugging
# - environment reporting
# - temporary config changes
# - reproducibility support
#
# ## One-line meaning
# **Top-level config helpers = framework debugging and control tools.**

# %% [markdown]
# # Part 2 — Data Preparation and Preprocessing Modules

# %% [markdown]
# # 8. sklearn.preprocessing
#
# ## Purpose
# Raw feature vectors ni downstream estimators ki suitable representation lo ki marchadaniki.
#
# ## Important classes/functions
# - StandardScaler
# - MinMaxScaler
# - RobustScaler
# - Normalizer
# - Binarizer
# - PolynomialFeatures
# - KBinsDiscretizer
# - OneHotEncoder
# - OrdinalEncoder
# - LabelEncoder
# - LabelBinarizer
# - FunctionTransformer
#
# ## One-line meaning
# **preprocessing = raw data ni model-friendly format lo marchadam.**

# %% [markdown]
# # 9. Scaling methods depth
#
# ## StandardScaler
# Mean 0, std 1
#
# ## MinMaxScaler
# Fixed range, usually 0 to 1
#
# ## RobustScaler
# Median + IQR based
#
# ## Normalizer
# Sample-wise norm scaling
#
# ## One-line meaning
# **Different scalers different data/algorithm needs ki suit avtayi.**

# %% [markdown]
# # 10. Encoding methods depth
#
# ## OneHotEncoder
# Categorical features ni binary columns ga expand chestundi
#
# ## OrdinalEncoder
# Categories ni integer ranks la encode chestundi
#
# ## LabelEncoder
# Mostly target labels kosam
#
# ## One-line meaning
# **Encoding = categories ni model-readable numbers ga marchadam.**

# %% [markdown]
# # 11. sklearn.impute
#
# ## Important classes
# - SimpleImputer
# - KNNImputer
# - IterativeImputer
# - MissingIndicator
#
# ## When to use
# - SimpleImputer → fast baseline
# - KNNImputer → similarity-based filling
# - IterativeImputer → feature relationships based filling
# - MissingIndicator → missingness itself signal ayithe
#
# ## One-line meaning
# **impute = missing values handling toolkit.**

# %% [markdown]
# # 12. sklearn.compose
#
# ## Important classes
# - ColumnTransformer
# - TransformedTargetRegressor
# - make_column_selector
#
# ## Why important?
# Different columns ki different preprocessing apply cheyyadaniki.
#
# ## One-line meaning
# **compose = column-wise workflow builder.**

# %% [markdown]
# # 13. sklearn.pipeline
#
# ## Important classes
# - Pipeline
# - make_pipeline
# - FeatureUnion
# - make_union
#
# ## Why important?
# - leakage reduce
# - preprocessing + model together tune cheyyachu
# - reproducibility better
#
# ## One-line meaning
# **pipeline = end-to-end ML steps ni single object ga marchadam.**

# %% [markdown]
# # Part 3 — Model Selection, Validation, and Metrics

# %% [markdown]
# # 14. sklearn.model_selection
#
# ## Important functions/classes
# - train_test_split
# - cross_val_score
# - cross_validate
# - cross_val_predict
# - KFold
# - StratifiedKFold
# - GroupKFold
# - TimeSeriesSplit
# - GridSearchCV
# - RandomizedSearchCV
# - learning_curve
# - validation_curve
# - ParameterGrid
# - ParameterSampler
#
# ## One-line meaning
# **model_selection = split, validate, compare, tune.**

# %% [markdown]
# # 15. train_test_split depth
#
# ## Important parameters
# - test_size
# - train_size
# - random_state
# - shuffle
# - stratify
#
# ## When stratify important?
# Imbalanced classification lo
#
# ## One-line meaning
# **Quick holdout split utility.**

# %% [markdown]
# # 16. Cross-validation classes depth
#
# ## KFold
# General splitting
#
# ## StratifiedKFold
# Class balance preserve cheyyadaniki
#
# ## GroupKFold
# Entity leakage avoid cheyyadaniki
#
# ## TimeSeriesSplit
# Temporal order preserve cheyyadaniki
#
# ## One-line meaning
# **Correct validation split = trustworthy evaluation.**

# %% [markdown]
# # 17. GridSearchCV vs RandomizedSearchCV
#
# ## GridSearchCV
# All combinations try chestundi
#
# ## RandomizedSearchCV
# Random combinations try chestundi
#
# ## One-line meaning
# **Grid = exhaustive small search, Randomized = efficient broad search.**

# %% [markdown]
# # 18. sklearn.metrics
#
# ## Classification metrics
# - accuracy_score
# - precision_score
# - recall_score
# - f1_score
# - roc_auc_score
# - average_precision_score
# - confusion_matrix
# - classification_report
# - log_loss
#
# ## Regression metrics
# - mean_absolute_error
# - mean_squared_error
# - r2_score
# - mean_absolute_percentage_error
#
# ## Clustering metrics
# - silhouette_score
# - adjusted_rand_score
# - davies_bouldin_score
# - calinski_harabasz_score
#
# ## Scorer helpers
# - make_scorer
# - get_scorer
# - get_scorer_names
# - check_scoring
#
# ## One-line meaning
# **metrics = model quality measurement center.**

# %% [markdown]
# # 19. Metrics selection mindset
#
# ## Why important?
# Default `score()` meeda blind ga rely kakudadhu.
#
# ## Example
# - classifier score often = accuracy
# - regressor score often = R²
#
# ## One-line meaning
# **Framework default score and business metric same ani assume cheyyakudadhu.**

# %% [markdown]
# # Part 4 — Supervised Learning Modules

# %% [markdown]
# # 20. sklearn.linear_model
#
# ## Important estimators
# - LinearRegression
# - Ridge
# - Lasso
# - ElasticNet
# - BayesianRidge
# - LogisticRegression
# - SGDClassifier
# - SGDRegressor
# - PassiveAggressiveClassifier
# - Perceptron
# - HuberRegressor
# - RANSACRegressor
#
# ## One-line meaning
# **linear_model = interpretable and strong baseline family.**

# %% [markdown]
# # 21. sklearn.svm
#
# ## Important estimators
# - SVC
# - SVR
# - LinearSVC
# - LinearSVR
# - OneClassSVM
# - NuSVC / NuSVR
#
# ## One-line meaning
# **svm = margin-based model family, powerful but scale-sensitive.**

# %% [markdown]
# # 22. sklearn.neighbors
#
# ## Important estimators
# - KNeighborsClassifier
# - KNeighborsRegressor
# - RadiusNeighborsClassifier
# - RadiusNeighborsRegressor
# - NearestNeighbors
#
# ## One-line meaning
# **neighbors = similarity-based learning and search.**

# %% [markdown]
# # 23. sklearn.naive_bayes
#
# ## Important estimators
# - GaussianNB
# - MultinomialNB
# - BernoulliNB
# - ComplementNB
# - CategoricalNB
#
# ## One-line meaning
# **naive_bayes = fast probabilistic classifier family.**

# %% [markdown]
# # 24. sklearn.tree
#
# ## Important estimators/tools
# - DecisionTreeClassifier
# - DecisionTreeRegressor
# - export_text
# - export_graphviz
# - plot_tree
#
# ## One-line meaning
# **tree = single-tree decision models and visualization tools.**

# %% [markdown]
# # 25. sklearn.ensemble
#
# ## Important estimators
# - RandomForestClassifier / Regressor
# - ExtraTreesClassifier / Regressor
# - GradientBoostingClassifier / Regressor
# - HistGradientBoostingClassifier / Regressor
# - AdaBoostClassifier / Regressor
# - BaggingClassifier / Regressor
# - VotingClassifier / Regressor
# - StackingClassifier / Regressor
# - IsolationForest
#
# ## One-line meaning
# **ensemble = many models combine chesi better performance.**

# %% [markdown]
# # 26. sklearn.neural_network
#
# ## Important estimators
# - MLPClassifier
# - MLPRegressor
# - BernoulliRBM
#
# ## One-line meaning
# **neural_network = small-scale classical NN support, not full DL ecosystem.**

# %% [markdown]
# # Part 5 — Unsupervised Learning and Dimensionality Reduction

# %% [markdown]
# # 27. sklearn.cluster
#
# ## Important estimators/functions
# - KMeans
# - MiniBatchKMeans
# - BisectingKMeans
# - DBSCAN
# - HDBSCAN
# - OPTICS
# - AgglomerativeClustering
# - SpectralClustering
# - MeanShift
# - Birch
# - AffinityPropagation
#
# ## One-line meaning
# **cluster = unlabeled structure discovery toolkit.**

# %% [markdown]
# # 28. sklearn.decomposition
#
# ## Important estimators
# - PCA
# - IncrementalPCA
# - KernelPCA
# - TruncatedSVD
# - NMF
# - SparsePCA
# - FastICA
# - DictionaryLearning
# - FactorAnalysis
# - LatentDirichletAllocation
#
# ## One-line meaning
# **decomposition = compress, separate, or discover latent structure.**

# %% [markdown]
# # 29. sklearn.manifold
#
# ## Important estimators
# - TSNE
# - Isomap
# - MDS
# - SpectralEmbedding
# - LocallyLinearEmbedding
#
# ## One-line meaning
# **manifold = non-linear structure visualization and embedding tools.**

# %% [markdown]
# # 30. sklearn.feature_selection
#
# ## Important tools
# - SelectKBest
# - SelectPercentile
# - chi2
# - f_classif
# - mutual_info_classif / regression
# - RFE
# - RFECV
# - SelectFromModel
# - SequentialFeatureSelector
# - VarianceThreshold
#
# ## One-line meaning
# **feature_selection = useful signal retain, noise reduce.**

# %% [markdown]
# # 31. sklearn.inspection
#
# ## Important tools
# - permutation_importance
# - partial_dependence
# - PartialDependenceDisplay
# - DecisionBoundaryDisplay
#
# ## One-line meaning
# **inspection = model behavior ni observe cheyyadaniki toolkit.**

# %% [markdown]
# # Part 6 — Specialized Modules and Utilities

# %% [markdown]
# # 32. sklearn.calibration
#
# ## Important tools
# - CalibratedClassifierCV
# - calibration_curve
# - CalibrationDisplay
#
# ## One-line meaning
# **calibration = probabilities ni reliable ga cheyyadam.**

# %% [markdown]
# # 33. sklearn.metrics.pairwise
#
# ## Important tools
# - cosine_similarity
# - euclidean_distances
# - pairwise_distances
# - rbf_kernel
# - linear_kernel
# - polynomial_kernel
#
# ## One-line meaning
# **pairwise = sample-to-sample similarity math toolkit.**

# %% [markdown]
# # 34. sklearn.kernel_approximation and sklearn.kernel_ridge
#
# ## kernel_approximation
# Approximate kernel feature maps
#
# ## kernel_ridge
# KernelRidge estimator
#
# ## One-line meaning
# **Kernel power ni scalable ga approximate/extend cheyyadaniki support.**

# %% [markdown]
# # 35. sklearn.covariance
#
# ## Important estimators
# - EmpiricalCovariance
# - LedoitWolf
# - OAS
# - MinCovDet
# - GraphicalLasso
#
# ## One-line meaning
# **covariance = covariance and precision structure estimation.**

# %% [markdown]
# # 36. sklearn.cross_decomposition
#
# ## Important estimators
# - PLSRegression
# - PLSCanonical
# - CCA
#
# ## One-line meaning
# **cross_decomposition = correlated latent relationships learn cheyyadam.**

# %% [markdown]
# # 37. sklearn.random_projection
#
# ## Important estimators
# - GaussianRandomProjection
# - SparseRandomProjection
#
# ## One-line meaning
# **random_projection = fast approximate dimension reduction.**

# %% [markdown]
# # 38. sklearn.semi_supervised
#
# ## Important estimators
# - LabelPropagation
# - LabelSpreading
# - SelfTrainingClassifier
#
# ## One-line meaning
# **semi_supervised = few labels tho inka ekkuva learning.**

# %% [markdown]
# # 39. sklearn.multiclass / sklearn.multioutput
#
# ## multiclass wrappers
# - OneVsRestClassifier
# - OneVsOneClassifier
# - OutputCodeClassifier
#
# ## multioutput tools
# - MultiOutputClassifier
# - MultiOutputRegressor
# - RegressorChain
# - ClassifierChain
#
# ## One-line meaning
# **wrappers = base models ni broader output settings ki extend cheyyadam.**

# %% [markdown]
# # 40. sklearn.dummy
#
# ## Important estimators
# - DummyClassifier
# - DummyRegressor
#
# ## One-line meaning
# **dummy = no-skill benchmark models.**

# %% [markdown]
# # 41. sklearn.isotonic
#
# ## Important estimator
# - IsotonicRegression
#
# ## One-line meaning
# **isotonic = monotonic relationship fitting.**

# %% [markdown]
# # Part 7 — API Utilities, Validation, Discovery, and Custom Estimators

# %% [markdown]
# # 42. sklearn.utils
#
# ## Important helpers
# - check_X_y
# - check_array
# - check_consistent_length
# - check_random_state
# - check_is_fitted
# - compute_class_weight
# - compute_sample_weight
# - resample
# - shuffle
# - safe_sparse_dot
# - randomized_svd
#
# ## One-line meaning
# **utils = framework plumbing and safety helpers.**

# %% [markdown]
# # 43. Discovery helpers
#
# ## Useful functions
# - all_estimators()
# - all_functions()
# - all_displays()
#
# ## One-line meaning
# **discovery helpers = sklearn ecosystem ni introspect cheyyadam.**

# %% [markdown]
# # 44. Custom estimator thinking
#
# ## Ideally support
# - fit
# - predict or transform
# - get_params
# - set_params
#
# ## Base helpers
# - BaseEstimator
# - ClassifierMixin
# - RegressorMixin
# - TransformerMixin
#
# ## One-line meaning
# **Custom estimator kuda sklearn conventions follow chesthe ecosystem-friendly avtundi.**

# %% [markdown]
# # Part 8 — Practical Project Flow with scikit-learn

# %% [markdown]
# # 45. Real-world tabular ML flow in scikit-learn
#
# ## Typical steps
# 1. load data
# 2. split data
# 3. define numeric / categorical columns
# 4. build imputers + scalers + encoders
# 5. combine with ColumnTransformer
# 6. attach model using Pipeline
# 7. evaluate with CV
# 8. tune with GridSearchCV / RandomizedSearchCV
# 9. inspect metrics
# 10. analyze errors
#
# ## One-line meaning
# **Best scikit-learn usage = pipeline-driven reproducible workflow.**

# %% [markdown]
# # 46. Why Pipeline + ColumnTransformer combo is so important
#
# ## Because real data lo
# - missing values
# - categories
# - different numeric scales
# untayi.
#
# ## Without pipeline
# - leakage chance
# - repeated code
# - inconsistent preprocessing
#
# ## With pipeline
# - clean workflow
# - safe CV
# - end-to-end tuning
# - reproducibility better
#
# ## One-line meaning
# **Pipeline + ColumnTransformer = real-world sklearn superpower.**

# %% [markdown]
# # 47. Common mistakes while using scikit-learn
#
# - preprocessing before split
# - LabelEncoder on feature columns blindly
# - wrong metric choose cheyyadam
# - default `score()` meeda over-rely avvadam
# - no stratification in imbalanced data
# - no pipeline use cheyyakapovadam
# - wrong CV split
# - feature leakage
# - over-tuning with weak baseline
#
# ## One-line meaning
# **scikit-learn easy anipinchina, workflow mistakes valla fake results ravachu.**

# %% [markdown]
# # 48. scikit-learn vs deep learning frameworks
#
# ## scikit-learn best for
# - classical ML
# - tabular data
# - preprocessing + pipelines
# - quick baselines
# - interpretable workflows
#
# ## PyTorch / TensorFlow best for
# - deep learning
# - large neural nets
# - GPUs
# - custom training loops
#
# ## One-line meaning
# **scikit-learn = classical ML king; DL frameworks = neural scale systems.**

# %% [markdown]
# # 49. How to think about “all methods and functions”
#
# ## Best learning strategy
# 1. estimator API master cheyyi
# 2. preprocessing + compose + pipeline master cheyyi
# 3. model_selection + metrics master cheyyi
# 4. top supervised/unsupervised modules cover cheyyi
# 5. advanced utilities and inspection later cover cheyyi
#
# ## One-line meaning
# **Framework ni structure-wise nerchukunte all functions manageable avtayi.**

# %% [markdown]
# # 50. Final master summary
#
# ## English
# scikit-learn is a unified framework for classical machine learning, not just a bag of algorithms. Its real power comes from the common estimator API, preprocessing tools, pipelines, model selection utilities, metrics ecosystem, and broad algorithm coverage.
#
# ## Telugu
# scikit-learn ante algorithms bag matrame kaadu; classical machine learning kosam unified framework. Dani real power common estimator API, preprocessing tools, pipelines, model selection utilities, metrics ecosystem, mariyu broad algorithm coverage nundi vastundi.
#
# ## One-line final meaning
# **Good scikit-learn usage = correct preprocessing + correct validation + correct metrics + correct pipeline design.**
